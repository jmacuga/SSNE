# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
path_to_csv = "../data/train_data.csv"
data = pd.read_csv(path_to_csv, index_col=0)

# %%
train_data, val_data = train_test_split(
    data,
    test_size=0.33,
    random_state=42,
)
# Out:
#            YearBuilt  Size(sqf)  Floor HallwayType         HeatingType  \
# SalePrice
# 75920           2005        572     17       mixed  individual_heating
# 260176          2007        868      9    terraced  individual_heating
# 389380          2015        914      7    terraced  individual_heating
# 79203           1992        576     13    corridor  individual_heating
# 218584          1993       1451     25       mixed  individual_heating
# ...              ...        ...    ...         ...                 ...
# 327433          2014        914     20    terraced  individual_heating
# 196460          2006        914     18    terraced  individual_heating
# 296460          2007        914     29    terraced  individual_heating
# 376106          2015        914      8    terraced  individual_heating
# 73840           2005        572     11       mixed  individual_heating
#
#                  AptManageType  N_Parkinglot(Ground)  N_Parkinglot(Basement)  \
# SalePrice
# ...

# %%
train_data.to_csv("../data/split_data/train_data.csv")
val_data.to_csv("../data/split_data/val_data.csv")
